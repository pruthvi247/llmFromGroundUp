# %% [markdown]
# # Rag From Scratch: Overview
# These notebooks walk through the process of building RAG app(s) from scratch.
#
# They will build towards a broader understanding of the RAG langscape, as shown here:
#
# ![image.png](attachment:image.png)

# %%
### # Environment
##! uv pip install langchain_community  langchain-openai langchainhub chromadb langchain
## Install additional dependencies for fallback embedding model
## ! uv pip install sentence-transformers faiss-cpu

# %%
## ! uv pip install "sap-ai-sdk-gen[all]"
